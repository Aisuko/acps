# %%
from typing import List, Dict, Tuple, Optional, Union, Any

import pandas as pd

from prompt_template_collection import PromptTemplate
from doraemon import Doraemon
from relaxed_fda import RelaxedFDA
from metrics_collection import MetricsHelper

task_name = "HotpotQA"
# Set up logger
logger = Doraemon.get_logger(name=task_name, logfile=f"cp_on_{task_name}.log")

# Prepare dataset with the logger passed as a parameter
file_path = '/kaggle/input/building-sots-on-hotpotqa-shuffled/sots_df.pkl'
grouped_data = RelaxedFDA.prepare_dataset(file_path=file_path, mode='r_s', logger=logger)

encoder=RelaxedFDA.get_encoder()

# Demo promts question, corect, and wrong 
D: List[Dict] = PromptTemplate.sot_construct_inter_hotpotqa()
logger.info(len(D))

op_system_prompt = RelaxedFDA.get_optimize_system_prompt(task_name)
logger.info(op_system_prompt)
# Out:
# 2025-06-24 03:08:58.820489: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1750734539.072973      13 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1750734539.140993      13 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-06-24 03:09:16,267 INFO Loaded dataset from /kaggle/input/building-sots-on-hotpotqa-shuffled/sots_df.pkl with shape (10673, 7)
# 2025-06-24 03:09:16,268 INFO In r_s mode.
# 2025-06-24 03:09:16,357 INFO Dataset preparation completed with 1196 entries.
# 2025-06-24 03:09:20,599 INFO 2
# 2025-06-24 03:09:20,600 INFO You are a concise and helpful assistant for multihop reasoning tasks. Provide step-by-step solutions, ensuring accuracy. Conclude with the final answer in the format: \boxed{answer}. When given a reasoning process, refine it to be both correct and succinct.

# %%
grouped_data[['question', 'context']] = grouped_data['question'].str.split(r'\nContext:', n=1, expand=True)
grouped_data['question']=grouped_data['question'].str.strip()
grouped_data['context']=grouped_data['context'].str.strip()

# %%
grouped_data.head()
# Out:
#                                             question  \
# 0  VIVA Media AG changed it's name in 2004. What ...
# 1    Woman's Era and Naj are what kind of magazines?
# 2  Jaclyn Stapp is married to the former frontman...
# 3  When was the  Argentine former footballer whic...
# 4  Stronger Together was used for the campaign co...
#
#                                      reasoning_paths  \
# 0  [<think>\nLet’s think through this step by ste...
# 1  [<think>\nLet’s think through this step by ste...
# 2  [<think>\nLet’s think through this step by ste...
# 3  [<think>\nLet’s think through this step by ste...
# 4  [<think>\nLet’s think through this step by ste...
#
#                             ground_truth  \
# 0  Gesellschaft mit beschränkter Haftung
# 1    fortnightly women interest magazine
# 2                                   2004
# 3                           2 March 1972
# 4                               Virginia
#
#                                               answer  \
# 0  [Gesellschaft mit beschränkter Haftung, Gesell...
# 1  [fortnightly women interest magazine, fortnigh...
# 2   [2004, 2004, 2004, 2004, 2004, 2004, 2004, 2004]
# 3  [2 March 1972, 2 March 1972, 2 March 1972, 2 M...
# 4  [Virginia, Virginia, Virginia, Virginia, Virgi...
#
#                                              context
# 0  A Gesellschaft mit beschränkter Haftung (] , a...
# 1  Naj is a Polish language fortnightly lifestyle...
# 2  The band's third album, "Weathered", was relea...
# 3  Mauricio Roberto Pochettino (] , ] ; born 2 Ma...
# 4  Timothy Michael Kaine ( , born February 26, 19...

# %%
result_pd: pd.DataFrame = RelaxedFDA.evaluate(
    grouped_data,
    logger,
    op_system_prompt,
    encoder,
    D,
    enable_logger_rs=False
)
# Out:
# 2025-06-24 03:09:21,336 INFO ====================================================================================================
# 2025-06-24 03:09:21,337 INFO Generated 8 valid reasoning path and embeddings.
# 2025-06-24 03:09:21,401 INFO Cluster 1: |C_0| = 3, P(r_0|do(X)) ≈ 0.38
# 2025-06-24 03:09:25,564 INFO Cluster 2: |C_1| = 1, P(r_1|do(X)) ≈ 0.12
# 2025-06-24 03:09:28,961 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.25
# 2025-06-24 03:09:32,384 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.25
# 2025-06-24 03:09:35,732 INFO Aggregated candidate votes (weighted): {'Gesellschaft\\ mit\\ beschränkter\\ Haftung': 0.7499999999999999}
# 2025-06-24 03:09:35,733 INFO Final aggregated answer is Gesellschaft\ mit\ beschränkter\ Haftung and weight 0.7499999999999999
# 2025-06-24 03:09:35,734 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:09:35,961 INFO ====================================================================================================
# 2025-06-24 03:09:35,962 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:09:35,975 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 03:09:38,333 INFO Cluster 2: |C_1| = 1, P(r_1|do(X)) ≈ 0.11
# 2025-06-24 03:09:41,174 INFO Cluster 3: |C_2| = 4, P(r_2|do(X)) ≈ 0.44
# 2025-06-24 03:09:43,887 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 03:09:46,625 INFO Aggregated candidate votes (weighted): {"women's magazines": 0.3333333333333333, 'fortnightly women interest magazine': 0.2962962962962963}
# 2025-06-24 03:09:46,626 INFO Final aggregated answer is women's magazines and weight 0.3333333333333333
# 2025-06-24 03:09:46,627 INFO Overall estimated probability (aggregated): 0.53
# 2025-06-24 03:09:46,823 INFO ====================================================================================================
# 2025-06-24 03:09:46,824 INFO Generated 8 valid reasoning path and embeddings.
# 2025-06-24 03:09:46,837 INFO Cluster 1: |C_0| = 4, P(r_0|do(X)) ≈ 0.50
# 2025-06-24 03:09:49,184 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.25
# 2025-06-24 03:09:51,455 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.12
# 2025-06-24 03:09:54,569 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.12
# 2025-06-24 03:09:56,834 INFO Aggregated candidate votes (weighted): {'2004': 1.0}
# 2025-06-24 03:09:56,835 INFO Final aggregated answer is 2004 and weight 1.0
# 2025-06-24 03:09:56,835 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:09:57,037 INFO ====================================================================================================
# 2025-06-24 03:09:57,038 INFO Generated 8 valid reasoning path and embeddings.
# 2025-06-24 03:09:57,051 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.12
# 2025-06-24 03:09:59,451 INFO Cluster 2: |C_1| = 4, P(r_1|do(X)) ≈ 0.50
# 2025-06-24 03:10:02,084 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.25
# 2025-06-24 03:10:05,959 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.12
# 2025-06-24 03:10:09,415 INFO Aggregated candidate votes (weighted): {'2 \\text{ March 1972': 0.9166666666666666}
# 2025-06-24 03:10:09,416 INFO Final aggregated answer is 2 \text{ March 1972 and weight 0.9166666666666666
# 2025-06-24 03:10:09,416 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:10:09,597 INFO ====================================================================================================
# 2025-06-24 03:10:09,598 INFO Generated 8 valid reasoning path and embeddings.
# 2025-06-24 03:10:09,611 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.12
# 2025-06-24 03:10:12,059 INFO Cluster 2: |C_1| = 4, P(r_1|do(X)) ≈ 0.50
# 2025-06-24 03:10:14,464 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.25
# 2025-06-24 03:10:17,315 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.12
# 2025-06-24 03:10:19,415 INFO Aggregated candidate votes (weighted): {'Virginia': 1.0}
# 2025-06-24 03:10:19,416 INFO Final aggregated answer is Virginia and weight 1.0
# 2025-06-24 03:10:19,417 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:10:19,579 INFO ====================================================================================================
# 2025-06-24 03:10:19,580 INFO Generated 8 valid reasoning path and embeddings.
# 2025-06-24 03:10:19,592 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.25
# 2025-06-24 03:10:21,750 INFO Cluster 2: |C_1| = 4, P(r_1|do(X)) ≈ 0.50
# 2025-06-24 03:10:24,068 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.12
# 2025-06-24 03:10:26,244 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.12
# 2025-06-24 03:10:28,677 INFO Aggregated candidate votes (weighted): {'no': 1.0}
# 2025-06-24 03:10:28,678 INFO Final aggregated answer is no and weight 1.0
# 2025-06-24 03:10:28,679 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:10:28,910 INFO ====================================================================================================
# 2025-06-24 03:10:28,911 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:10:28,924 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:10:31,543 INFO Cluster 2: |C_1| = 3, P(r_1|do(X)) ≈ 0.33
# 2025-06-24 03:10:33,959 INFO Cluster 3: |C_2| = 4, P(r_2|do(X)) ≈ 0.44
# 2025-06-24 03:10:36,838 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:10:39,607 INFO Aggregated candidate votes (weighted): {'2011 Pulitzer Prize in General Nonfiction': 1.0}
# 2025-06-24 03:10:39,608 INFO Final aggregated answer is 2011 Pulitzer Prize in General Nonfiction and weight 1.0
# 2025-06-24 03:10:39,609 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:10:39,795 INFO ====================================================================================================
# 2025-06-24 03:10:39,796 INFO Generated 9 valid reasoning path and embeddings.
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (2) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# 2025-06-24 03:10:39,813 INFO Cluster 1: |C_0| = 4, P(r_0|do(X)) ≈ 0.44
# 2025-06-24 03:10:42,107 INFO Cluster 2: |C_1| = 5, P(r_1|do(X)) ≈ 0.56
# 2025-06-24 03:10:45,378 INFO Cluster 3: No items found
# 2025-06-24 03:10:45,379 INFO Cluster 4: No items found
# 2025-06-24 03:10:45,380 INFO Aggregated candidate votes (weighted): {'Hawaii County': 1.0}
# 2025-06-24 03:10:45,381 INFO Final aggregated answer is Hawaii County and weight 1.0
# 2025-06-24 03:10:45,381 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:10:45,585 INFO ====================================================================================================
# 2025-06-24 03:10:45,586 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:10:45,599 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:10:47,854 INFO Cluster 2: |C_1| = 3, P(r_1|do(X)) ≈ 0.33
# 2025-06-24 03:10:50,082 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 03:10:52,322 INFO Cluster 4: |C_3| = 3, P(r_3|do(X)) ≈ 0.33
# 2025-06-24 03:10:54,533 INFO Aggregated candidate votes (weighted): {'Sam Boyd Stadium': 1.0}
# 2025-06-24 03:10:54,534 INFO Final aggregated answer is Sam Boyd Stadium and weight 1.0
# 2025-06-24 03:10:54,535 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:10:54,719 INFO ====================================================================================================
# 2025-06-24 03:10:54,720 INFO Generated 7 valid reasoning path and embeddings.
# 2025-06-24 03:10:54,733 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.14
# 2025-06-24 03:10:57,759 INFO Cluster 2: |C_1| = 4, P(r_1|do(X)) ≈ 0.57
# 2025-06-24 03:11:00,283 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.14
# 2025-06-24 03:11:02,921 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.14
# 2025-06-24 03:11:05,571 INFO Aggregated candidate votes (weighted): {'1941': 0.9999999999999998}
# 2025-06-24 03:11:05,572 INFO Final aggregated answer is 1941 and weight 0.9999999999999998
# 2025-06-24 03:11:05,573 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:11:05,769 INFO ====================================================================================================
# 2025-06-24 03:11:05,771 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:11:05,784 INFO Cluster 1: |C_0| = 3, P(r_0|do(X)) ≈ 0.33
# 2025-06-24 03:11:08,310 INFO Cluster 2: |C_1| = 1, P(r_1|do(X)) ≈ 0.11
# 2025-06-24 03:11:11,451 INFO Cluster 3: |C_2| = 3, P(r_2|do(X)) ≈ 0.33
# 2025-06-24 03:11:14,163 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 03:11:16,605 INFO Aggregated candidate votes (weighted): {'10 \\text{ January 1920': 0.9999999999999999}
# 2025-06-24 03:11:16,606 INFO Final aggregated answer is 10 \text{ January 1920 and weight 0.9999999999999999
# 2025-06-24 03:11:16,608 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:11:16,776 INFO ====================================================================================================
# 2025-06-24 03:11:16,777 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:11:16,789 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:11:18,980 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:11:20,895 INFO Cluster 3: |C_2| = 4, P(r_2|do(X)) ≈ 0.44
# 2025-06-24 03:11:23,829 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 03:11:25,911 INFO Aggregated candidate votes (weighted): {'super-regional shopping mall': 0.4074074074074074, 'shopping\\ mall': 0.2222222222222222, 'super-regional\\ shopping\\ mall': 0.14814814814814814}
# 2025-06-24 03:11:25,912 INFO Final aggregated answer is super-regional shopping mall and weight 0.4074074074074074
# 2025-06-24 03:11:25,913 INFO Overall estimated probability (aggregated): 0.52
# 2025-06-24 03:11:26,181 INFO ====================================================================================================
# 2025-06-24 03:11:26,182 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:11:26,196 INFO Cluster 1: |C_0| = 3, P(r_0|do(X)) ≈ 0.33
# 2025-06-24 03:11:29,264 INFO Cluster 2: |C_1| = 3, P(r_1|do(X)) ≈ 0.33
# 2025-06-24 03:11:32,648 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:11:35,576 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 03:11:38,365 INFO Aggregated candidate votes (weighted): {'M. Night Shyamalan': 0.9999999999999999}
# 2025-06-24 03:11:38,366 INFO Final aggregated answer is M. Night Shyamalan and weight 0.9999999999999999
# 2025-06-24 03:11:38,367 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:11:38,529 INFO ====================================================================================================
# 2025-06-24 03:11:38,530 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:11:38,543 INFO Cluster 1: |C_0| = 5, P(r_0|do(X)) ≈ 0.56
# 2025-06-24 03:11:40,984 INFO Cluster 2: |C_1| = 1, P(r_1|do(X)) ≈ 0.11
# 2025-06-24 03:11:44,002 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:11:46,881 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 03:11:49,596 INFO Aggregated candidate votes (weighted): {'1978': 1.0}
# 2025-06-24 03:11:49,598 INFO Final aggregated answer is 1978 and weight 1.0
# 2025-06-24 03:11:49,598 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:11:49,792 INFO ====================================================================================================
# 2025-06-24 03:11:49,793 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:11:49,808 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 03:11:52,581 INFO Cluster 2: |C_1| = 3, P(r_1|do(X)) ≈ 0.33
# 2025-06-24 03:11:54,675 INFO Cluster 3: |C_2| = 3, P(r_2|do(X)) ≈ 0.33
# 2025-06-24 03:11:57,608 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:12:00,223 INFO Aggregated candidate votes (weighted): {'Edinburgh': 0.5555555555555556, 'London': 0.4074074074074074}
# 2025-06-24 03:12:00,224 INFO Final aggregated answer is Edinburgh and weight 0.5555555555555556
# 2025-06-24 03:12:00,224 INFO Overall estimated probability (aggregated): 0.58
# 2025-06-24 03:12:00,409 INFO ====================================================================================================
# 2025-06-24 03:12:00,410 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:12:00,426 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:12:02,535 INFO Cluster 2: |C_1| = 4, P(r_1|do(X)) ≈ 0.44
# 2025-06-24 03:12:04,342 INFO Cluster 3: |C_2| = 3, P(r_2|do(X)) ≈ 0.33
# 2025-06-24 03:12:06,456 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:12:08,593 INFO Aggregated candidate votes (weighted): {'no': 1.0}
# 2025-06-24 03:12:08,594 INFO Final aggregated answer is no and weight 1.0
# 2025-06-24 03:12:08,595 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:12:08,843 INFO ====================================================================================================
# 2025-06-24 03:12:08,844 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:12:08,857 INFO Cluster 1: |C_0| = 5, P(r_0|do(X)) ≈ 0.56
# 2025-06-24 03:12:12,617 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:12:16,298 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:12:18,642 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:12:22,455 INFO Aggregated candidate votes (weighted): {'his works': 0.5555555555555556, 'critical\\ quotations': 0.2222222222222222, 'collection of critical quotations': 0.1111111111111111, 'Timeline of Shakespeare criticism': 0.1111111111111111}
# 2025-06-24 03:12:22,456 INFO Final aggregated answer is his works and weight 0.5555555555555556
# 2025-06-24 03:12:22,457 INFO Overall estimated probability (aggregated): 0.56
# 2025-06-24 03:12:22,669 INFO ====================================================================================================
# 2025-06-24 03:12:22,670 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:12:22,684 INFO Cluster 1: |C_0| = 3, P(r_0|do(X)) ≈ 0.33
# 2025-06-24 03:12:25,135 INFO Cluster 2: |C_1| = 3, P(r_1|do(X)) ≈ 0.33
# 2025-06-24 03:12:27,431 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 03:12:30,656 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:12:33,736 INFO Aggregated candidate votes (weighted): {'22 \\text{ November 1761': 0.4444444444444444, '22 November 1761': 0.3333333333333333, '17 \\text{ January 1801': 0.14814814814814814}
# 2025-06-24 03:12:33,737 INFO Final aggregated answer is 22 \text{ November 1761 and weight 0.4444444444444444
# 2025-06-24 03:12:33,738 INFO Overall estimated probability (aggregated): 0.48
# 2025-06-24 03:12:33,943 INFO ====================================================================================================
# 2025-06-24 03:12:33,944 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:12:33,958 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 03:12:36,574 INFO Cluster 2: |C_1| = 4, P(r_1|do(X)) ≈ 0.44
# 2025-06-24 03:12:39,189 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 03:12:42,302 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:12:45,144 INFO Aggregated candidate votes (weighted): {'Dubai International Airport': 0.6666666666666666, 'Terminal 2 of Dubai International Airport': 0.2222222222222222}
# 2025-06-24 03:12:45,145 INFO Final aggregated answer is Dubai International Airport and weight 0.6666666666666666
# 2025-06-24 03:12:45,146 INFO Overall estimated probability (aggregated): 0.75
# 2025-06-24 03:12:45,328 INFO ====================================================================================================
# 2025-06-24 03:12:45,329 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:12:45,341 INFO Cluster 1: |C_0| = 4, P(r_0|do(X)) ≈ 0.44
# 2025-06-24 03:12:48,827 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:12:51,621 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:12:54,627 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 03:12:57,599 INFO Aggregated candidate votes (weighted): {'1927': 0.9999999999999999}
# 2025-06-24 03:12:57,600 INFO Final aggregated answer is 1927 and weight 0.9999999999999999
# 2025-06-24 03:12:57,600 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:12:57,823 INFO ====================================================================================================
# 2025-06-24 03:12:57,824 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:12:57,837 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:13:00,574 INFO Cluster 2: |C_1| = 5, P(r_1|do(X)) ≈ 0.56
# 2025-06-24 03:13:03,131 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 03:13:05,610 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:13:08,173 INFO Aggregated candidate votes (weighted): {"Papa Gino's": 1.0}
# 2025-06-24 03:13:08,175 INFO Final aggregated answer is Papa Gino's and weight 1.0
# 2025-06-24 03:13:08,176 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:13:08,412 INFO ====================================================================================================
# 2025-06-24 03:13:08,412 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:13:08,425 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 03:13:09,753 INFO Cluster 2: |C_1| = 4, P(r_1|do(X)) ≈ 0.44
# 2025-06-24 03:13:11,070 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 03:13:13,521 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:13:17,227 INFO Aggregated candidate votes (weighted): {'The correct answer is: "Shukratara by Date"': 0.2222222222222222, '"Shukratara"': 0.4444444444444444, 'Shukratara': 0.3333333333333333}
# 2025-06-24 03:13:17,228 INFO Final aggregated answer is "Shukratara" and weight 0.4444444444444444
# 2025-06-24 03:13:17,229 INFO Overall estimated probability (aggregated): 0.44
# 2025-06-24 03:13:17,436 INFO ====================================================================================================
# 2025-06-24 03:13:17,437 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:13:17,452 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:13:20,115 INFO Cluster 2: |C_1| = 5, P(r_1|do(X)) ≈ 0.56
# 2025-06-24 03:13:22,982 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 03:13:25,766 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:13:27,988 INFO Aggregated candidate votes (weighted): {'Captain\\ Hans\\ Geering': 0.48148148148148145, 'Captain Hans Geering': 0.2222222222222222}
# 2025-06-24 03:13:27,989 INFO Final aggregated answer is Captain\ Hans\ Geering and weight 0.48148148148148145
# 2025-06-24 03:13:27,990 INFO Overall estimated probability (aggregated): 0.68
# 2025-06-24 03:13:28,181 INFO ====================================================================================================
# 2025-06-24 03:13:28,182 INFO Generated 9 valid reasoning path and embeddings.
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# 2025-06-24 03:13:28,197 INFO Cluster 1: |C_0| = 9, P(r_0|do(X)) ≈ 1.00
# 2025-06-24 03:13:30,472 INFO Cluster 2: No items found
# 2025-06-24 03:13:30,473 INFO Cluster 3: No items found
# 2025-06-24 03:13:30,474 INFO Cluster 4: No items found
# 2025-06-24 03:13:30,475 INFO Aggregated candidate votes (weighted): {'Frederick Lindemann': 1.0}
# 2025-06-24 03:13:30,475 INFO Final aggregated answer is Frederick Lindemann and weight 1.0
# 2025-06-24 03:13:30,476 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:13:30,646 INFO ====================================================================================================
# 2025-06-24 03:13:30,647 INFO Generated 9 valid reasoning path and embeddings.
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# 2025-06-24 03:13:30,661 INFO Cluster 1: |C_0| = 6, P(r_0|do(X)) ≈ 0.67
# 2025-06-24 03:13:33,001 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:13:35,269 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:13:37,785 INFO Cluster 4: No items found
# 2025-06-24 03:13:37,786 INFO Aggregated candidate votes (weighted): {'Marktown': 1.0}
# 2025-06-24 03:13:37,787 INFO Final aggregated answer is Marktown and weight 1.0
# 2025-06-24 03:13:37,788 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:13:38,010 INFO ====================================================================================================
# 2025-06-24 03:13:38,011 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:13:38,025 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 03:13:40,550 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:13:43,862 INFO Cluster 3: |C_2| = 4, P(r_2|do(X)) ≈ 0.44
# 2025-06-24 03:13:46,828 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:13:49,360 INFO Aggregated candidate votes (weighted): {'Stone Brewing': 0.2222222222222222, 'Stone Brewing Co.': 0.7777777777777777}
# 2025-06-24 03:13:49,361 INFO Final aggregated answer is Stone Brewing Co. and weight 0.7777777777777777
# 2025-06-24 03:13:49,361 INFO Overall estimated probability (aggregated): 0.78
# 2025-06-24 03:13:49,552 INFO ====================================================================================================
# 2025-06-24 03:13:49,554 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:13:49,567 INFO Cluster 1: |C_0| = 5, P(r_0|do(X)) ≈ 0.56
# 2025-06-24 03:13:51,700 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:13:54,120 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:13:56,427 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:13:59,015 INFO Aggregated candidate votes (weighted): {'Baudot code': 1.0}
# 2025-06-24 03:13:59,016 INFO Final aggregated answer is Baudot code and weight 1.0
# 2025-06-24 03:13:59,017 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:13:59,173 INFO ====================================================================================================
# 2025-06-24 03:13:59,174 INFO Generated 7 valid reasoning path and embeddings.
# 2025-06-24 03:13:59,187 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.29
# 2025-06-24 03:14:03,257 INFO Cluster 2: |C_1| = 3, P(r_1|do(X)) ≈ 0.43
# 2025-06-24 03:14:05,976 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.14
# 2025-06-24 03:14:08,395 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.14
# 2025-06-24 03:14:11,099 INFO Aggregated candidate votes (weighted): {'Raffaella Reggi': 0.2857142857142857, 'Raffaella\\ Reggi': 0.6666666666666666}
# 2025-06-24 03:14:11,100 INFO Final aggregated answer is Raffaella\ Reggi and weight 0.6666666666666666
# 2025-06-24 03:14:11,101 INFO Overall estimated probability (aggregated): 0.70
# 2025-06-24 03:14:11,271 INFO ====================================================================================================
# 2025-06-24 03:14:11,272 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:14:11,286 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:14:13,325 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:14:15,240 INFO Cluster 3: |C_2| = 5, P(r_2|do(X)) ≈ 0.56
# 2025-06-24 03:14:17,145 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:14:19,543 INFO Aggregated candidate votes (weighted): {'no': 1.0}
# 2025-06-24 03:14:19,544 INFO Final aggregated answer is no and weight 1.0
# 2025-06-24 03:14:19,545 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:14:19,723 INFO ====================================================================================================
# 2025-06-24 03:14:19,724 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:14:19,737 INFO Cluster 1: |C_0| = 4, P(r_0|do(X)) ≈ 0.44
# 2025-06-24 03:14:21,977 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:14:24,168 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 03:14:26,267 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:14:28,518 INFO Aggregated candidate votes (weighted): {'Stedelijk Museum Amsterdam': 0.8888888888888888, 'Stedelijk Museum': 0.1111111111111111}
# 2025-06-24 03:14:28,519 INFO Final aggregated answer is Stedelijk Museum Amsterdam and weight 0.8888888888888888
# 2025-06-24 03:14:28,520 INFO Overall estimated probability (aggregated): 0.89
# 2025-06-24 03:14:28,694 INFO ====================================================================================================
# 2025-06-24 03:14:28,695 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:14:28,708 INFO Cluster 1: |C_0| = 6, P(r_0|do(X)) ≈ 0.67
# 2025-06-24 03:14:30,946 INFO Cluster 2: |C_1| = 1, P(r_1|do(X)) ≈ 0.11
# 2025-06-24 03:14:33,125 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:14:35,604 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:14:37,425 INFO Aggregated candidate votes (weighted): {'Aloe Vera of America': 1.0}
# 2025-06-24 03:14:37,427 INFO Final aggregated answer is Aloe Vera of America and weight 1.0
# 2025-06-24 03:14:37,427 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:14:37,641 INFO ====================================================================================================
# 2025-06-24 03:14:37,642 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:14:37,656 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 03:14:38,923 INFO Cluster 2: |C_1| = 4, P(r_1|do(X)) ≈ 0.44
# 2025-06-24 03:14:42,133 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:14:44,592 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 03:14:46,269 INFO Aggregated candidate votes (weighted): {'Sarah Kerrigan': 0.9999999999999999}
# 2025-06-24 03:14:46,270 INFO Final aggregated answer is Sarah Kerrigan and weight 0.9999999999999999
# 2025-06-24 03:14:46,271 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:14:46,462 INFO ====================================================================================================
# 2025-06-24 03:14:46,463 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:14:46,476 INFO Cluster 1: |C_0| = 4, P(r_0|do(X)) ≈ 0.44
# 2025-06-24 03:14:49,105 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:14:52,072 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:14:54,626 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 03:14:57,390 INFO Aggregated candidate votes (weighted): {'2016 Cannes Film Festival': 0.6666666666666666, '2016\\ Cannes\\ Film\\ Festival': 0.2222222222222222}
# 2025-06-24 03:14:57,391 INFO Final aggregated answer is 2016 Cannes Film Festival and weight 0.6666666666666666
# 2025-06-24 03:14:57,392 INFO Overall estimated probability (aggregated): 0.75
# 2025-06-24 03:14:57,591 INFO ====================================================================================================
# 2025-06-24 03:14:57,591 INFO Generated 9 valid reasoning path and embeddings.
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (3) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# 2025-06-24 03:14:57,607 INFO Cluster 1: |C_0| = 5, P(r_0|do(X)) ≈ 0.56
# 2025-06-24 03:15:00,965 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:15:04,076 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 03:15:06,474 INFO Cluster 4: No items found
# 2025-06-24 03:15:06,475 INFO Aggregated candidate votes (weighted): {'yes': 1.0}
# 2025-06-24 03:15:06,475 INFO Final aggregated answer is yes and weight 1.0
# 2025-06-24 03:15:06,477 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:15:06,682 INFO ====================================================================================================
# 2025-06-24 03:15:06,683 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:15:06,696 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 03:15:08,936 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:15:10,959 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:15:13,264 INFO Cluster 4: |C_3| = 4, P(r_3|do(X)) ≈ 0.44
# 2025-06-24 03:15:15,294 INFO Aggregated candidate votes (weighted): {'Adam Levine': 1.0}
# 2025-06-24 03:15:15,296 INFO Final aggregated answer is Adam Levine and weight 1.0
# 2025-06-24 03:15:15,296 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:15:15,474 INFO ====================================================================================================
# 2025-06-24 03:15:15,475 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:15:15,488 INFO Cluster 1: |C_0| = 3, P(r_0|do(X)) ≈ 0.33
# 2025-06-24 03:15:17,850 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:15:20,714 INFO Cluster 3: |C_2| = 3, P(r_2|do(X)) ≈ 0.33
# 2025-06-24 03:15:23,233 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:15:26,061 INFO Aggregated candidate votes (weighted): {'San Francisco, California': 1.0}
# 2025-06-24 03:15:26,062 INFO Final aggregated answer is San Francisco, California and weight 1.0
# 2025-06-24 03:15:26,063 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:15:26,267 INFO ====================================================================================================
# 2025-06-24 03:15:26,268 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:15:26,281 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 03:15:29,071 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:15:32,013 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:15:34,399 INFO Cluster 4: |C_3| = 4, P(r_3|do(X)) ≈ 0.44
# 2025-06-24 03:15:37,307 INFO Aggregated candidate votes (weighted): {'Indiana University': 1.0}
# 2025-06-24 03:15:37,308 INFO Final aggregated answer is Indiana University and weight 1.0
# 2025-06-24 03:15:37,309 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:15:37,537 INFO ====================================================================================================
# 2025-06-24 03:15:37,538 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:15:37,551 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 03:15:40,818 INFO Cluster 2: |C_1| = 5, P(r_1|do(X)) ≈ 0.56
# 2025-06-24 03:15:43,669 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:15:46,535 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:15:49,706 INFO Aggregated candidate votes (weighted): {'Roman Empire': 0.9629629629629629}
# 2025-06-24 03:15:49,706 INFO Final aggregated answer is Roman Empire and weight 0.9629629629629629
# 2025-06-24 03:15:49,707 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:15:49,910 INFO ====================================================================================================
# 2025-06-24 03:15:49,911 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:15:49,924 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:15:54,367 INFO Cluster 2: |C_1| = 6, P(r_1|do(X)) ≈ 0.67
# 2025-06-24 03:15:57,035 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:15:59,656 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:16:02,532 INFO Aggregated candidate votes (weighted): {'The Story of Us': 0.1111111111111111, 'Now\\ and\\ Then': 0.7777777777777777, 'Runaway Bride': 0.1111111111111111}
# 2025-06-24 03:16:02,533 INFO Final aggregated answer is Now\ and\ Then and weight 0.7777777777777777
# 2025-06-24 03:16:02,534 INFO Overall estimated probability (aggregated): 0.78
# 2025-06-24 03:16:02,750 INFO ====================================================================================================
# 2025-06-24 03:16:02,751 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:16:02,764 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 03:16:06,421 INFO Cluster 2: |C_1| = 5, P(r_1|do(X)) ≈ 0.56
# 2025-06-24 03:16:09,920 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:16:14,479 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:16:15,794 INFO Aggregated candidate votes (weighted): {'Ian Boothby': 1.0}
# 2025-06-24 03:16:15,795 INFO Final aggregated answer is Ian Boothby and weight 1.0
# 2025-06-24 03:16:15,796 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:16:15,977 INFO ====================================================================================================
# 2025-06-24 03:16:15,978 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:16:15,990 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:16:18,068 INFO Cluster 2: |C_1| = 1, P(r_1|do(X)) ≈ 0.11
# 2025-06-24 03:16:21,190 INFO Cluster 3: |C_2| = 6, P(r_2|do(X)) ≈ 0.67
# 2025-06-24 03:16:24,274 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:16:26,817 INFO Aggregated candidate votes (weighted): {'KXII': 1.0}
# 2025-06-24 03:16:26,818 INFO Final aggregated answer is KXII and weight 1.0
# 2025-06-24 03:16:26,819 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:16:27,010 INFO ====================================================================================================
# 2025-06-24 03:16:27,011 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:16:27,025 INFO Cluster 1: |C_0| = 4, P(r_0|do(X)) ≈ 0.44
# 2025-06-24 03:16:29,766 INFO Cluster 2: |C_1| = 3, P(r_1|do(X)) ≈ 0.33
# 2025-06-24 03:16:32,715 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:16:36,716 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:16:39,967 INFO Aggregated candidate votes (weighted): {'Crystal Dynamics': 1.0}
# 2025-06-24 03:16:39,968 INFO Final aggregated answer is Crystal Dynamics and weight 1.0
# 2025-06-24 03:16:39,969 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:16:40,159 INFO ====================================================================================================
# 2025-06-24 03:16:40,160 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:16:40,174 INFO Cluster 1: |C_0| = 3, P(r_0|do(X)) ≈ 0.33
# 2025-06-24 03:16:42,535 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:16:44,936 INFO Cluster 3: |C_2| = 3, P(r_2|do(X)) ≈ 0.33
# 2025-06-24 03:16:47,989 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:16:50,739 INFO Aggregated candidate votes (weighted): {'Aquilo': 0.3333333333333333, 'Enigma': 0.6666666666666667}
# 2025-06-24 03:16:50,740 INFO Final aggregated answer is Enigma and weight 0.6666666666666667
# 2025-06-24 03:16:50,741 INFO Overall estimated probability (aggregated): 0.67
# 2025-06-24 03:16:50,933 INFO ====================================================================================================
# 2025-06-24 03:16:50,934 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:16:50,947 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:16:53,655 INFO Cluster 2: |C_1| = 3, P(r_1|do(X)) ≈ 0.33
# 2025-06-24 03:16:56,487 INFO Cluster 3: |C_2| = 4, P(r_2|do(X)) ≈ 0.44
# 2025-06-24 03:16:59,631 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:17:02,286 INFO Aggregated candidate votes (weighted): {'singer-songwriters': 0.2222222222222222, 'singer, songwriter': 0.3333333333333333, 'singer \\ and \\ songwriter': 0.4444444444444444}
# 2025-06-24 03:17:02,287 INFO Final aggregated answer is singer \ and \ songwriter and weight 0.4444444444444444
# 2025-06-24 03:17:02,287 INFO Overall estimated probability (aggregated): 0.44
# 2025-06-24 03:17:02,519 INFO ====================================================================================================
# 2025-06-24 03:17:02,520 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:17:02,534 INFO Cluster 1: |C_0| = 3, P(r_0|do(X)) ≈ 0.33
# 2025-06-24 03:17:06,350 INFO Cluster 2: |C_1| = 3, P(r_1|do(X)) ≈ 0.33
# 2025-06-24 03:17:08,950 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 03:17:11,891 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:17:14,713 INFO Aggregated candidate votes (weighted): {'cleaning, catering, security services': 0.5555555555555556, 'cleaning, catering, security': 0.2222222222222222, 'cleaning and catering': 0.07407407407407407}
# 2025-06-24 03:17:14,714 INFO Final aggregated answer is cleaning, catering, security services and weight 0.5555555555555556
# 2025-06-24 03:17:14,715 INFO Overall estimated probability (aggregated): 0.65
# 2025-06-24 03:17:14,864 INFO ====================================================================================================
# 2025-06-24 03:17:14,865 INFO Generated 8 valid reasoning path and embeddings.
# 2025-06-24 03:17:14,878 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.12
# 2025-06-24 03:17:17,698 INFO Cluster 2: |C_1| = 5, P(r_1|do(X)) ≈ 0.62
# 2025-06-24 03:17:21,216 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.12
# 2025-06-24 03:17:23,507 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.12
# 2025-06-24 03:17:26,008 INFO Aggregated candidate votes (weighted): {"You're Next": 0.125, '"You\'re Next"': 0.8333333333333334}
# 2025-06-24 03:17:26,009 INFO Final aggregated answer is "You're Next" and weight 0.8333333333333334
# 2025-06-24 03:17:26,010 INFO Overall estimated probability (aggregated): 0.87
# 2025-06-24 03:17:26,186 INFO ====================================================================================================
# 2025-06-24 03:17:26,187 INFO Generated 6 valid reasoning path and embeddings.
# 2025-06-24 03:17:26,200 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.33
# 2025-06-24 03:17:29,790 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.33
# 2025-06-24 03:17:33,315 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.17
# 2025-06-24 03:17:37,027 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.17
# 2025-06-24 03:17:40,553 INFO Aggregated candidate votes (weighted): {'Blue Grass Airport': 0.9999999999999999}
# 2025-06-24 03:17:40,554 INFO Final aggregated answer is Blue Grass Airport and weight 0.9999999999999999
# 2025-06-24 03:17:40,555 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:17:40,734 INFO ====================================================================================================
# 2025-06-24 03:17:40,735 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:17:40,748 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:17:42,952 INFO Cluster 2: |C_1| = 1, P(r_1|do(X)) ≈ 0.11
# 2025-06-24 03:17:45,393 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 03:17:47,854 INFO Cluster 4: |C_3| = 5, P(r_3|do(X)) ≈ 0.56
# 2025-06-24 03:17:50,287 INFO Aggregated candidate votes (weighted): {'6': 1.0}
# 2025-06-24 03:17:50,288 INFO Final aggregated answer is 6 and weight 1.0
# 2025-06-24 03:17:50,289 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:17:50,476 INFO ====================================================================================================
# 2025-06-24 03:17:50,477 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:17:50,490 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 03:17:52,906 INFO Cluster 2: |C_1| = 3, P(r_1|do(X)) ≈ 0.33
# 2025-06-24 03:17:55,557 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 03:17:58,089 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 03:18:00,339 INFO Aggregated candidate votes (weighted): {'Martha Coolidge': 1.0}
# 2025-06-24 03:18:00,340 INFO Final aggregated answer is Martha Coolidge and weight 1.0
# 2025-06-24 03:18:00,341 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:18:00,553 INFO ====================================================================================================
# 2025-06-24 03:18:00,553 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:18:00,567 INFO Cluster 1: |C_0| = 4, P(r_0|do(X)) ≈ 0.44
# 2025-06-24 03:18:03,218 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:18:07,567 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:18:10,444 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 03:18:13,255 INFO Aggregated candidate votes (weighted): {'Battle\\ of\\ White\\ Plains': 0.2962962962962963, 'Battle of White Plains': 0.5555555555555556}
# 2025-06-24 03:18:13,257 INFO Final aggregated answer is Battle of White Plains and weight 0.5555555555555556
# 2025-06-24 03:18:13,257 INFO Overall estimated probability (aggregated): 0.65
# 2025-06-24 03:18:13,445 INFO ====================================================================================================
# 2025-06-24 03:18:13,446 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:18:13,459 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:18:15,841 INFO Cluster 2: |C_1| = 5, P(r_1|do(X)) ≈ 0.56
# 2025-06-24 03:18:18,268 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 03:18:20,774 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:18:23,653 INFO Aggregated candidate votes (weighted): {'1983': 1.0}
# 2025-06-24 03:18:23,654 INFO Final aggregated answer is 1983 and weight 1.0
# 2025-06-24 03:18:23,655 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:18:23,837 INFO ====================================================================================================
# 2025-06-24 03:18:23,838 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:18:23,851 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:18:26,557 INFO Cluster 2: |C_1| = 6, P(r_1|do(X)) ≈ 0.67
# 2025-06-24 03:18:28,500 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:18:30,976 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:18:33,523 INFO Aggregated candidate votes (weighted): {'The Dark Tower': 1.0}
# 2025-06-24 03:18:33,524 INFO Final aggregated answer is The Dark Tower and weight 1.0
# 2025-06-24 03:18:33,525 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:18:33,721 INFO ====================================================================================================
# 2025-06-24 03:18:33,722 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:18:33,736 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:18:35,965 INFO Cluster 2: |C_1| = 4, P(r_1|do(X)) ≈ 0.44
# 2025-06-24 03:18:38,537 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:18:40,708 INFO Cluster 4: |C_3| = 3, P(r_3|do(X)) ≈ 0.33
# 2025-06-24 03:18:43,297 INFO Aggregated candidate votes (weighted): {'Bhaktivedanta Manor': 0.888888888888889}
# 2025-06-24 03:18:43,298 INFO Final aggregated answer is Bhaktivedanta Manor and weight 0.888888888888889
# 2025-06-24 03:18:43,298 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:18:43,530 INFO ====================================================================================================
# 2025-06-24 03:18:43,531 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:18:43,544 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:18:46,333 INFO Cluster 2: |C_1| = 3, P(r_1|do(X)) ≈ 0.33
# 2025-06-24 03:18:49,299 INFO Cluster 3: |C_2| = 4, P(r_2|do(X)) ≈ 0.44
# 2025-06-24 03:18:52,481 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 03:18:55,033 INFO Aggregated candidate votes (weighted): {'J. R. R. Tolkien': 1.0}
# 2025-06-24 03:18:55,034 INFO Final aggregated answer is J. R. R. Tolkien and weight 1.0
# 2025-06-24 03:18:55,035 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:18:55,225 INFO ====================================================================================================
# 2025-06-24 03:18:55,226 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:18:55,240 INFO Cluster 1: |C_0| = 3, P(r_0|do(X)) ≈ 0.33
# 2025-06-24 03:18:58,854 INFO Cluster 2: |C_1| = 3, P(r_1|do(X)) ≈ 0.33
# 2025-06-24 03:19:01,632 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:19:04,413 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 03:19:07,428 INFO Aggregated candidate votes (weighted): {'from the port of Baltimore west to Sandy Hook': 0.6666666666666666, 'from Baltimore west to Sandy Hook': 0.2222222222222222}
# 2025-06-24 03:19:07,429 INFO Final aggregated answer is from the port of Baltimore west to Sandy Hook and weight 0.6666666666666666
# 2025-06-24 03:19:07,430 INFO Overall estimated probability (aggregated): 0.75
# 2025-06-24 03:19:07,637 INFO ====================================================================================================
# 2025-06-24 03:19:07,638 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:19:07,651 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 03:19:10,247 INFO Cluster 2: |C_1| = 4, P(r_1|do(X)) ≈ 0.44
# 2025-06-24 03:19:12,680 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:19:15,434 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 03:19:18,496 INFO Aggregated candidate votes (weighted): {'magical English nanny': 0.5185185185185185, 'magical\\ English\\ nanny': 0.1111111111111111, 'Mary\\ Poppins': 0.07407407407407407}
# 2025-06-24 03:19:18,497 INFO Final aggregated answer is magical English nanny and weight 0.5185185185185185
# 2025-06-24 03:19:18,498 INFO Overall estimated probability (aggregated): 0.74
# 2025-06-24 03:19:18,703 INFO ====================================================================================================
# 2025-06-24 03:19:18,704 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:19:18,717 INFO Cluster 1: |C_0| = 4, P(r_0|do(X)) ≈ 0.44
# 2025-06-24 03:19:20,469 INFO Cluster 2: |C_1| = 1, P(r_1|do(X)) ≈ 0.11
# 2025-06-24 03:19:22,717 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 03:19:24,928 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 03:19:27,194 INFO Aggregated candidate votes (weighted): {'World War I and World War II': 0.7777777777777778, 'World War I and II': 0.2222222222222222}
# 2025-06-24 03:19:27,195 INFO Final aggregated answer is World War I and World War II and weight 0.7777777777777778
# 2025-06-24 03:19:27,197 INFO Overall estimated probability (aggregated): 0.78
# 2025-06-24 03:19:27,387 INFO ====================================================================================================
# 2025-06-24 03:19:27,388 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:19:27,406 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 03:19:29,815 INFO Cluster 2: |C_1| = 4, P(r_1|do(X)) ≈ 0.44
# 2025-06-24 03:19:32,499 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 03:19:35,234 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 03:19:37,951 INFO Aggregated candidate votes (weighted): {'writing': 1.0}
# 2025-06-24 03:19:37,952 INFO Final aggregated answer is writing and weight 1.0
# 2025-06-24 03:19:37,953 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 03:19:38,149 INFO ====================================================================================================
# 2025-06-24 03:19:38,151 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:19:38,164 INFO Cluster 1: |C_0| = 4, P(r_0|do(X)) ≈ 0.44
# 2025-06-24 03:19:41,104 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 03:19:44,055 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 03:19:47,084 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 03:19:50,381 INFO Aggregated candidate votes (weighted): {'Larnelle Steward Harris': 0.8888888888888888, 'Larnelle Harris': 0.1111111111111111}
# 2025-06-24 03:19:50,383 INFO Final aggregated answer is Larnelle Steward Harris and weight 0.8888888888888888
# 2025-06-24 03:19:50,384 INFO Overall estimated probability (aggregated): 0.89
# 2025-06-24 03:19:50,622 INFO ====================================================================================================
# 2025-06-24 03:19:50,623 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 03:19:50,637 INFO Cluster 1: |C_0| = 6, P(r_0|do(X)) ≈ 0.67
# ...
# 2025-06-24 08:07:34,858 INFO Cluster 4: No items found
# 2025-06-24 08:07:34,859 INFO Aggregated candidate votes (weighted): {'yes': 1.0}
# 2025-06-24 08:07:34,860 INFO Final aggregated answer is yes and weight 1.0
# 2025-06-24 08:07:34,861 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 08:07:35,023 INFO ====================================================================================================
# 2025-06-24 08:07:35,024 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:07:35,037 INFO Cluster 1: |C_0| = 5, P(r_0|do(X)) ≈ 0.56
# 2025-06-24 08:07:37,368 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 08:07:40,044 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 08:07:43,446 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 08:07:45,661 INFO Aggregated candidate votes (weighted): {'Jim Kerr': 0.5555555555555556, 'Shirley Manson': 0.4074074074074074}
# 2025-06-24 08:07:45,662 INFO Final aggregated answer is Jim Kerr and weight 0.5555555555555556
# 2025-06-24 08:07:45,663 INFO Overall estimated probability (aggregated): 0.58
# 2025-06-24 08:07:45,839 INFO ====================================================================================================
# 2025-06-24 08:07:45,840 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:07:45,853 INFO Cluster 1: |C_0| = 3, P(r_0|do(X)) ≈ 0.33
# 2025-06-24 08:07:47,848 INFO Cluster 2: |C_1| = 4, P(r_1|do(X)) ≈ 0.44
# 2025-06-24 08:07:49,850 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 08:07:52,432 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 08:07:54,735 INFO Aggregated candidate votes (weighted): {'Australia': 1.0}
# 2025-06-24 08:07:54,736 INFO Final aggregated answer is Australia and weight 1.0
# 2025-06-24 08:07:54,737 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 08:07:54,906 INFO ====================================================================================================
# 2025-06-24 08:07:54,907 INFO Generated 8 valid reasoning path and embeddings.
# 2025-06-24 08:07:54,923 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.12
# 2025-06-24 08:07:56,800 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.25
# 2025-06-24 08:08:00,295 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.25
# 2025-06-24 08:08:03,116 INFO Cluster 4: |C_3| = 3, P(r_3|do(X)) ≈ 0.38
# 2025-06-24 08:08:05,268 INFO Aggregated candidate votes (weighted): {'Washington': 1.0}
# 2025-06-24 08:08:05,269 INFO Final aggregated answer is Washington and weight 1.0
# 2025-06-24 08:08:05,270 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 08:08:05,424 INFO ====================================================================================================
# 2025-06-24 08:08:05,425 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:08:05,438 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 08:08:08,353 INFO Cluster 2: |C_1| = 5, P(r_1|do(X)) ≈ 0.56
# 2025-06-24 08:08:09,994 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 08:08:11,204 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 08:08:13,347 INFO Aggregated candidate votes (weighted): {'1838': 1.0}
# 2025-06-24 08:08:13,348 INFO Final aggregated answer is 1838 and weight 1.0
# 2025-06-24 08:08:13,349 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 08:08:13,511 INFO ====================================================================================================
# 2025-06-24 08:08:13,511 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:08:13,525 INFO Cluster 1: |C_0| = 4, P(r_0|do(X)) ≈ 0.44
# 2025-06-24 08:08:15,838 INFO Cluster 2: |C_1| = 1, P(r_1|do(X)) ≈ 0.11
# 2025-06-24 08:08:17,798 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 08:08:20,067 INFO Cluster 4: |C_3| = 3, P(r_3|do(X)) ≈ 0.33
# 2025-06-24 08:08:22,347 INFO Aggregated candidate votes (weighted): {'yes': 0.6666666666666667, 'no': 0.2222222222222222}
# 2025-06-24 08:08:22,348 INFO Final aggregated answer is yes and weight 0.6666666666666667
# 2025-06-24 08:08:22,349 INFO Overall estimated probability (aggregated): 0.75
# 2025-06-24 08:08:22,538 INFO ====================================================================================================
# 2025-06-24 08:08:22,539 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:08:22,553 INFO Cluster 1: |C_0| = 4, P(r_0|do(X)) ≈ 0.44
# 2025-06-24 08:08:25,485 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 08:08:29,010 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 08:08:32,914 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 08:08:35,864 INFO Aggregated candidate votes (weighted): {'Pat McCarran': 0.8888888888888888}
# 2025-06-24 08:08:35,865 INFO Final aggregated answer is Pat McCarran and weight 0.8888888888888888
# 2025-06-24 08:08:35,866 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 08:08:36,070 INFO ====================================================================================================
# 2025-06-24 08:08:36,071 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:08:36,085 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 08:08:37,510 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 08:08:40,379 INFO Cluster 3: |C_2| = 4, P(r_2|do(X)) ≈ 0.44
# 2025-06-24 08:08:42,036 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 08:08:44,336 INFO Aggregated candidate votes (weighted): {'Eucritta\\ melanolimnetes': 0.9629629629629629}
# 2025-06-24 08:08:44,337 INFO Final aggregated answer is Eucritta\ melanolimnetes and weight 0.9629629629629629
# 2025-06-24 08:08:44,338 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 08:08:44,508 INFO ====================================================================================================
# 2025-06-24 08:08:44,509 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:08:44,522 INFO Cluster 1: |C_0| = 3, P(r_0|do(X)) ≈ 0.33
# 2025-06-24 08:08:46,929 INFO Cluster 2: |C_1| = 3, P(r_1|do(X)) ≈ 0.33
# 2025-06-24 08:08:49,960 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 08:08:52,595 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 08:08:54,876 INFO Aggregated candidate votes (weighted): {'quantum~mechanics': 0.4444444444444444, 'quantum mechanics': 0.4444444444444444}
# 2025-06-24 08:08:54,877 INFO Final aggregated answer is quantum~mechanics and weight 0.4444444444444444
# 2025-06-24 08:08:54,877 INFO Overall estimated probability (aggregated): 0.50
# 2025-06-24 08:08:55,068 INFO ====================================================================================================
# 2025-06-24 08:08:55,069 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:08:55,083 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 08:08:56,394 INFO Cluster 2: |C_1| = 6, P(r_1|do(X)) ≈ 0.67
# 2025-06-24 08:08:57,664 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 08:08:59,329 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 08:09:00,545 INFO Aggregated candidate votes (weighted): {'yes': 0.8888888888888888, 'no': 0.07407407407407407}
# 2025-06-24 08:09:00,546 INFO Final aggregated answer is yes and weight 0.8888888888888888
# 2025-06-24 08:09:00,547 INFO Overall estimated probability (aggregated): 0.92
# 2025-06-24 08:09:00,830 INFO ====================================================================================================
# 2025-06-24 08:09:00,831 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:09:00,845 INFO Cluster 1: |C_0| = 4, P(r_0|do(X)) ≈ 0.44
# 2025-06-24 08:09:03,455 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 08:09:05,834 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 08:09:08,590 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 08:09:10,983 INFO Aggregated candidate votes (weighted): {'Queens': 0.9999999999999999}
# 2025-06-24 08:09:10,984 INFO Final aggregated answer is Queens and weight 0.9999999999999999
# 2025-06-24 08:09:10,985 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 08:09:11,190 INFO ====================================================================================================
# 2025-06-24 08:09:11,191 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:09:11,204 INFO Cluster 1: |C_0| = 3, P(r_0|do(X)) ≈ 0.33
# 2025-06-24 08:09:14,275 INFO Cluster 2: |C_1| = 2, P(r_1|do(X)) ≈ 0.22
# 2025-06-24 08:09:17,232 INFO Cluster 3: |C_2| = 3, P(r_2|do(X)) ≈ 0.33
# 2025-06-24 08:09:20,476 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 08:09:23,727 INFO Aggregated candidate votes (weighted): {'science\\ fiction\\ drama': 1.0}
# 2025-06-24 08:09:23,728 INFO Final aggregated answer is science\ fiction\ drama and weight 1.0
# 2025-06-24 08:09:23,729 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 08:09:23,909 INFO ====================================================================================================
# 2025-06-24 08:09:23,910 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:09:23,924 INFO Cluster 1: |C_0| = 5, P(r_0|do(X)) ≈ 0.56
# 2025-06-24 08:09:27,058 INFO Cluster 2: |C_1| = 1, P(r_1|do(X)) ≈ 0.11
# 2025-06-24 08:09:28,759 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 08:09:31,513 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 08:09:35,384 INFO Aggregated candidate votes (weighted): {'Folkets Hus': 1.0}
# 2025-06-24 08:09:35,385 INFO Final aggregated answer is Folkets Hus and weight 1.0
# 2025-06-24 08:09:35,386 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 08:09:35,559 INFO ====================================================================================================
# 2025-06-24 08:09:35,560 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:09:35,573 INFO Cluster 1: |C_0| = 6, P(r_0|do(X)) ≈ 0.67
# 2025-06-24 08:09:38,924 INFO Cluster 2: |C_1| = 1, P(r_1|do(X)) ≈ 0.11
# 2025-06-24 08:09:41,257 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 08:09:43,232 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 08:09:45,683 INFO Aggregated candidate votes (weighted): {'Isaak Dunayevsky': 0.7777777777777777, 'Grigori Aleksandrov': 0.2222222222222222}
# 2025-06-24 08:09:45,684 INFO Final aggregated answer is Isaak Dunayevsky and weight 0.7777777777777777
# 2025-06-24 08:09:45,685 INFO Overall estimated probability (aggregated): 0.78
# 2025-06-24 08:09:45,875 INFO ====================================================================================================
# 2025-06-24 08:09:45,876 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:09:45,889 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 08:09:48,602 INFO Cluster 2: |C_1| = 4, P(r_1|do(X)) ≈ 0.44
# 2025-06-24 08:09:50,911 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 08:09:53,178 INFO Cluster 4: |C_3| = 2, P(r_3|do(X)) ≈ 0.22
# 2025-06-24 08:09:55,476 INFO Aggregated candidate votes (weighted): {'Spam musubi': 0.14814814814814814, 'Spam': 0.5555555555555556}
# 2025-06-24 08:09:55,476 INFO Final aggregated answer is Spam and weight 0.5555555555555556
# 2025-06-24 08:09:55,477 INFO Overall estimated probability (aggregated): 0.79
# 2025-06-24 08:09:55,662 INFO ====================================================================================================
# 2025-06-24 08:09:55,663 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:09:55,676 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 08:09:58,611 INFO Cluster 2: |C_1| = 6, P(r_1|do(X)) ≈ 0.67
# 2025-06-24 08:10:01,754 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 08:10:03,867 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 08:10:06,835 INFO Aggregated candidate votes (weighted): {'Chiwetel Ejiofor': 1.0}
# 2025-06-24 08:10:06,836 INFO Final aggregated answer is Chiwetel Ejiofor and weight 1.0
# 2025-06-24 08:10:06,837 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 08:10:07,029 INFO ====================================================================================================
# 2025-06-24 08:10:07,030 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:10:07,044 INFO Cluster 1: |C_0| = 2, P(r_0|do(X)) ≈ 0.22
# 2025-06-24 08:10:10,393 INFO Cluster 2: |C_1| = 1, P(r_1|do(X)) ≈ 0.11
# 2025-06-24 08:10:12,833 INFO Cluster 3: |C_2| = 2, P(r_2|do(X)) ≈ 0.22
# 2025-06-24 08:10:16,053 INFO Cluster 4: |C_3| = 4, P(r_3|do(X)) ≈ 0.44
# 2025-06-24 08:10:19,367 INFO Aggregated candidate votes (weighted): {'New York City': 0.2962962962962963, 'Buffalo': 0.1111111111111111, 'no': 0.2222222222222222}
# 2025-06-24 08:10:19,368 INFO Final aggregated answer is New York City and weight 0.2962962962962963
# 2025-06-24 08:10:19,369 INFO Overall estimated probability (aggregated): 0.47
# 2025-06-24 08:10:19,554 INFO ====================================================================================================
# 2025-06-24 08:10:19,555 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:10:19,568 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 08:10:21,060 INFO Cluster 2: |C_1| = 4, P(r_1|do(X)) ≈ 0.44
# 2025-06-24 08:10:23,663 INFO Cluster 3: |C_2| = 3, P(r_2|do(X)) ≈ 0.33
# 2025-06-24 08:10:26,041 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 08:10:30,526 INFO Aggregated candidate votes (weighted): {'Carl Nielsen': 0.4444444444444444, 'Carl August Nielsen': 0.4444444444444444}
# 2025-06-24 08:10:30,527 INFO Final aggregated answer is Carl Nielsen and weight 0.4444444444444444
# 2025-06-24 08:10:30,528 INFO Overall estimated probability (aggregated): 0.50
# 2025-06-24 08:10:30,730 INFO ====================================================================================================
# 2025-06-24 08:10:30,731 INFO Generated 9 valid reasoning path and embeddings.
# /usr/local/lib/python3.11/dist-packages/sklearn/cluster/_kmeans.py:1033: ConvergenceWarning: Number of distinct clusters (1) found smaller than n_clusters (4). Possibly due to duplicate points in X.
#   return self.fit(X, sample_weight=sample_weight).labels_
# 2025-06-24 08:10:30,746 INFO Cluster 1: |C_0| = 9, P(r_0|do(X)) ≈ 1.00
# 2025-06-24 08:10:32,806 INFO Cluster 2: No items found
# 2025-06-24 08:10:32,807 INFO Cluster 3: No items found
# 2025-06-24 08:10:32,808 INFO Cluster 4: No items found
# 2025-06-24 08:10:32,809 INFO Aggregated candidate votes (weighted): {'fixed-roof': 1.0}
# 2025-06-24 08:10:32,809 INFO Final aggregated answer is fixed-roof and weight 1.0
# 2025-06-24 08:10:32,810 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 08:10:32,993 INFO ====================================================================================================
# 2025-06-24 08:10:32,994 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:10:33,007 INFO Cluster 1: |C_0| = 6, P(r_0|do(X)) ≈ 0.67
# 2025-06-24 08:10:35,572 INFO Cluster 2: |C_1| = 1, P(r_1|do(X)) ≈ 0.11
# 2025-06-24 08:10:38,391 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 08:10:41,150 INFO Cluster 4: |C_3| = 1, P(r_3|do(X)) ≈ 0.11
# 2025-06-24 08:10:43,862 INFO Aggregated candidate votes (weighted): {'7pm': 1.0}
# 2025-06-24 08:10:43,863 INFO Final aggregated answer is 7pm and weight 1.0
# 2025-06-24 08:10:43,864 INFO Overall estimated probability (aggregated): 1.00
# 2025-06-24 08:10:44,066 INFO ====================================================================================================
# 2025-06-24 08:10:44,067 INFO Generated 9 valid reasoning path and embeddings.
# 2025-06-24 08:10:44,080 INFO Cluster 1: |C_0| = 1, P(r_0|do(X)) ≈ 0.11
# 2025-06-24 08:10:48,072 INFO Cluster 2: |C_1| = 3, P(r_1|do(X)) ≈ 0.33
# 2025-06-24 08:10:51,070 INFO Cluster 3: |C_2| = 1, P(r_2|do(X)) ≈ 0.11
# 2025-06-24 08:10:54,179 INFO Cluster 4: |C_3| = 4, P(r_3|do(X)) ≈ 0.44
# 2025-06-24 08:10:57,112 INFO Aggregated candidate votes (weighted): {'Elie Wiesel': 1.0}
# 2025-06-24 08:10:57,113 INFO Final aggregated answer is Elie Wiesel and weight 1.0
# 2025-06-24 08:10:57,113 INFO Overall estimated probability (aggregated): 1.00

# %%
MetricsHelper.evaluate(result_pd, logger)
# Out:
# 2025-06-24 08:10:58,360 INFO Evaluated 1196 examples
# 2025-06-24 08:10:58,361 INFO Exact Match: 720/1196 = 60.20%
# 2025-06-24 08:10:58,362 INFO Average F1 Score: 75.84%
